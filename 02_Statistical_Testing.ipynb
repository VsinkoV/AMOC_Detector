# %% [markdown]
# **Papers i like**
# https://arxiv.org/pdf/2002.09116
# https://proceedings.neurips.cc/paper_files/paper/2015/file/eb1e78328c46506b46a4ac4a1e378b91-Paper.pdf
#
# **https://arxiv.org/html/2505.16082v1**
#
#
# **https://www.imperial.ac.uk/media/imperial-college/faculty-of-natural-sciences/department-of-mathematics/math-finance/239236448---Hugo-Ng---Ng_Hugo_01848839.pdf**

# %% [markdown]
# A vague idea of what I had in mind when I first proposed this project:
#
# 1. Decide on some selection of changepoints. An example set may be, gaussian change in mean, gaussian change in variance, gaussian change to some heavier tailed distribution (and many else, if you want to). There are also options for going from 1 dimension to higher dimensions.
# 2. For each change, design a correctly specified parametric detector, using cost functions designed to look for the changes we are actually searching for. Get the type of power graphs we have been talking about from these.
# 3. Now, try and detect the same changes with kernel based methods.
# 	(the following questions may seem a bit boring, and in all honesty they might be. However they are genuinely important to have a good answer to. I currently do not have good answers to all of them)
# 	a. how should each detector be set up? What is the null hypothesis we are supposing, hence how should we tune the threshold beta?
# 	b. how should we pick the length scale? Re run the tuning on every sample? what about if we fix it beforehand whilst we are doing monte carlo sim to get some false positive rate.
# 4. Compare multiple kernels to one another. Does one capture changes in tail behaviour noticeable easier? do some work better for different types of change? e.g., for gaussian change in mean perhaps rbf is best, but for lorentzian change in mean, maybe a different kernel does better.
# 5. (optional) is there any theory we can do to support any conclusions we find in step 4?

# %%
from AMOC_Detector import Detector, gaussian_mean_change, rbf_kernel, median_heuristic, gaussian_variance_change, gaussian_meanvar_change, kfdr, kfdr_curve, polynomial_kernel
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from arch import arch_model
from scipy.stats import cauchy, skewnorm, norm, t
from scipy.interpolate import PchipInterpolator
from functools import partial
from numpy.typing import NDArray
from statsmodels.tsa.arima_process import ArmaProcess
import os
os.makedirs("plots", exist_ok=True)
os.makedirs("data", exist_ok=True)

# %% [markdown]
# ***Some changes we will work with***

# %%
def mean_change(ts, changepoint: int, delta: float, **kwargs) -> np.ndarray:
    """Location shift. Variance and shape unchanged."""
    ts_new = ts.copy()
    ts_new[changepoint:] += delta
    return ts_new


# The null generator is N(LOC, SCALE^2): the notebook draws with
# mean=np.ones(dim), cov=np.eye(dim), so LOC = SCALE = 1.0.
LOC, SCALE = 1.0, 1.0


def variance_change(ts, changepoint: int, delta: float, loc: float = LOC, **kwargs) -> np.ndarray:
    """Pure scale change about the pre-change mean; mean unchanged.

    Previously this multiplied the raw values, which scaled the mean too
    (1 -> delta), making it a mean-and-variance change.
    """
    ts_new = ts.copy()
    ts_new[changepoint:] = loc + (ts_new[changepoint:] - loc) * delta
    return ts_new


def shape_change(ts, changepoint: int, delta: float, beta: float, **kwargs) -> np.ndarray:
    ts_new = ts.copy()
    ts_new[changepoint:] = ts_new[changepoint:] * delta + beta
    return ts_new


def cauchy_change(ts, changepoint: int, delta: float, beta: float,
                  loc: float = LOC, **kwargs) -> np.ndarray:
    """Replace by a Cauchy: no finite moments, so nothing can be matched."""
    ts_new = ts.copy()
    ts_new[changepoint:] = cauchy.rvs(loc=loc, scale=beta, size=ts_new[changepoint:].shape)
    return ts_new


def skewness_change(ts, changepoint: int, delta: float,
                    loc: float = LOC, scale: float = SCALE, **kwargs) -> np.ndarray:

    ts_new = ts.copy()
    tail_shape = ts_new[changepoint:].shape
    d = delta / np.sqrt(1.0 + delta ** 2)
    w = 1.0 / np.sqrt(1.0 - 2.0 * d ** 2 / np.pi)      # unit variance
    xi = -w * d * np.sqrt(2.0 / np.pi)                 # zero mean
    z = skewnorm.rvs(a=delta, loc=xi, scale=w, size=tail_shape)
    ts_new[changepoint:] = loc + scale * z
    return ts_new


def kurtosis_change(ts, changepoint: int, delta: float,
                    loc: float = LOC, scale: float = SCALE, **kwargs) -> np.ndarray:

    if delta <= 4:
        raise ValueError("kurtosis_change: delta (degrees of freedom) must exceed 4")
    ts_new = ts.copy()
    tail_shape = ts_new[changepoint:].shape
    z = t.rvs(df=delta, size=tail_shape) * np.sqrt((delta - 2.0) / delta)
    ts_new[changepoint:] = loc + scale * z
    return ts_new


def multimodal_change(ts, changepoint: int, delta: float,
                      loc: float = LOC, scale: float = SCALE, **kwargs) -> np.ndarray:
    if not 0.0 <= delta < 1.0:
        raise ValueError("multimodal_change: delta (=m) must lie in [0, 1)")
    ts_new = ts.copy()
    tail_shape = ts_new[changepoint:].shape
    comp = np.random.choice([-1.0, 1.0], size=tail_shape) * delta
    z = comp + np.random.standard_normal(tail_shape) * np.sqrt(1.0 - delta ** 2)
    ts_new[changepoint:] = loc + scale * z
    return ts_new

# %%
colors = {
    "mean_change": "#2a78d6",      # blue
    "variance_change": "#eb6834",  # orange
    "shape_change": "#1baf7a",     # aqua
    "cauchy_change": "#eda100",    # yellow
    "skewness_change": "#9b59b6",  # purple
    "kurtosis_change": "#e74c3c",  # red
    "multimodal_change": "#16a085",# teal
}

fns = {
    "mean_change": lambda ts, cp: mean_change(ts, cp, delta=10),
    "variance_change": lambda ts, cp: variance_change(ts, cp, delta=10),
    "shape_change": lambda ts, cp: shape_change(ts, cp, delta=5, beta=10),
    "cauchy_change": lambda ts, cp: cauchy_change(ts, cp, delta=2, beta=2),
    "skewness_change": lambda ts, cp: skewness_change(ts, cp, delta=8),
    "kurtosis_change": lambda ts, cp: kurtosis_change(ts, cp, delta=6),
    "multimodal_change": lambda ts, cp: multimodal_change(ts, cp, delta=0.85),
}

fig, axes = plt.subplots(3, 3, figsize=(15, 9))
fig.patch.set_facecolor("#fcfcfb")
rng = np.random.default_rng(0)

for ax, (name, fn) in zip(axes.flat, fns.items()):
    ts = rng.multivariate_normal(mean=np.zeros(1), cov=np.eye(1), size=500)
    changepoint = 250
    ts_shifted = fn(ts, changepoint)

    ax.plot(ts_shifted[:, 0], color=colors[name], linewidth=1.1)
    ax.axvline(changepoint, color="#898781", linestyle="--", linewidth=1)

    ax.set_facecolor("#fcfcfb")
    ax.set_title(name.replace("_", " ").title(), color="#0b0b0b", fontsize=12, fontweight="bold", loc="left")
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#c3c2b7")
    ax.spines["bottom"].set_color("#c3c2b7")
    ax.tick_params(colors="#898781", labelsize=8)
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.7)
    ax.set_axisbelow(True)

for ax in axes.flat[len(fns):]:
    ax.axis("off")

fig.supxlabel("time index", color="#52514e", fontsize=10)
fig.supylabel("value", color="#52514e", fontsize=10)
fig.tight_layout()
fig.savefig("plots/change_types_demo.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# This is a very basic function for beta tuning our values using using MC methods to find the 0.05 percentile, this is in order to create that the chances of a mis calculation

# %%
def beta_tuning(alpha, cost_function, dim, n=500) -> float:
    maxima = []
    for i in range(1000):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        maxima.append(np.max(cost_function(ts)))
    return float(np.quantile(maxima, 1 - alpha))

# %% [markdown]
# Our benchmark that we will be using is an oracle statistic, this works simply by allowing our test to have the full information and the change point to create the optimal segmentation for our Cusum Statistic, this seems counter intutive but the only time we will reject it, it will

# %%
def oracle_statistic_mean(timeseries: NDArray, t: int) -> float:
    x = np.asarray(timeseries, dtype=float).reshape(len(timeseries), -1)
    n = len(timeseries)
    cs = np.vstack((np.zeros(x.shape[1]), np.cumsum(x, axis=0)))
    left, right = cs[t] / t, (cs[n] - cs[t]) / (n - t)
    out = t * (n - t) / n * np.sum((left - right) ** 2)
    return out

def oracle_statistic_var(timeseries: NDArray, t: int) -> float:
    x = np.asarray(timeseries, dtype=float).reshape(len(timeseries), -1)
    n = len(x)
    cs = np.vstack((np.zeros(x.shape[1]), np.cumsum(x**2, axis=0)))
    out = n * np.log(cs[n] / n) - t * np.log(cs[t] / t) - (n - t) * np.log((cs[n] - cs[t]) / (n - t))
    return float(np.sum(out))

def oracle_statistic_meanvar(timeseries: NDArray, t: int) -> float:
    
    x = np.asarray(timeseries, dtype=float).reshape(len(timeseries), -1)
    n = len(x)
    cs1 = np.vstack((np.zeros(x.shape[1]), np.cumsum(x, axis=0)))
    cs2 = np.vstack((np.zeros(x.shape[1]), np.cumsum(x**2, axis=0)))

    def seg_var(a, b):
        m = b - a
        s1 = cs1[b] - cs1[a]
        s2 = cs2[b] - cs2[a]
        return s2 / m - (s1 / m) ** 2

    total_var = seg_var(0, n)
    left_var = seg_var(0, t)
    right_var = seg_var(t, n)
    out = n * np.log(total_var) - t * np.log(left_var) - (n - t) * np.log(right_var)
    return float(np.sum(out))

def oracle_statistic_skew(timeseries: NDArray, t: int, delta: float,
                           loc: float = LOC, scale: float = SCALE) -> float:

    x = np.asarray(timeseries, dtype=float).reshape(len(timeseries), -1)
    d = delta / np.sqrt(1.0 + delta ** 2)
    w = 1.0 / np.sqrt(1.0 - 2.0 * d ** 2 / np.pi)
    xi = -w * d * np.sqrt(2.0 / np.pi)
    post_loc = loc + scale * xi
    post_scale = scale * w

    right = x[t:]
    f1 = skewnorm.logpdf(right, a=delta, loc=post_loc, scale=post_scale)
    f0 = norm.logpdf(right, loc=loc, scale=scale)
    return float(np.sum(f1 - f0))

def oracle_statistic_multimodal(timeseries: NDArray, t: int, delta: float,
                                 loc: float = LOC, scale: float = SCALE) -> float:

    x = np.asarray(timeseries, dtype=float).reshape(len(timeseries), -1)
    mix_scale = scale * np.sqrt(1.0 - delta ** 2)

    right = x[t:]
    f1 = np.logaddexp(
        norm.logpdf(right, loc=loc + scale * delta, scale=mix_scale),
        norm.logpdf(right, loc=loc - scale * delta, scale=mix_scale),
    ) - np.log(2.0)
    f0 = norm.logpdf(right, loc=loc, scale=scale)
    return float(np.sum(f1 - f0))

#So for a fixed value of t, or adjusting 
def oracle_beta_tuning_mean(alpha, dim, n=500) -> float:
    stats = []
    for i in range(1000):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        stats.append(oracle_statistic_mean(timeseries=ts, t=n//2))
    return float(np.quantile(stats, 1 - alpha))

def oracle_beta_tuning_var(alpha, dim, n=500) -> float:
    stats = []
    for i in range(1000):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        stats.append(oracle_statistic_var(timeseries=ts, t=n//2))
    return float(np.quantile(stats, 1 - alpha))

def oracle_beta_tuning_meanvar(alpha, dim, n=500) -> float:
    stats = []
    for i in range(1000):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        stats.append(oracle_statistic_meanvar(timeseries=ts, t=n//2))
    return float(np.quantile(stats, 1 - alpha))

def oracle_beta_tuning_skew(alpha, dim, delta, n=500) -> float:
    stats = []
    for i in range(1000):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        stats.append(oracle_statistic_skew(timeseries=ts, t=n//2, delta=delta))
    return float(np.quantile(stats, 1 - alpha))

def oracle_beta_tuning_multimodal(alpha, dim, delta, n=500) -> float:
    stats = []
    for i in range(1000):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        stats.append(oracle_statistic_multimodal(timeseries=ts, t=n//2, delta=delta))
    return float(np.quantile(stats, 1 - alpha))

# %%
def kfdr_tuning(alpha, dim, n=500) -> float:
    stats = []
    for i in range(1000):
        time_series = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        stats.append(np.max(kfdr_curve(time_series)))
    return float(np.quantile(stats, 1 - alpha))

# %% [markdown]
# **Some comments**
#
#
# 5th Aug 2025- Originally I selected a random value from $\operatorname{U}(0.025n , 0.975n)$ , however now I have realised that these cause degredation of power for our test statistic, with it being scaled by $\frac{t(n-t)}{n}$. Move it to $0.1n$ our power falls by rougly 5 so therefore it is wise that we do not infact change the value from $n//2$

# %%
def statistical_test_v1(change_type_fn, delta, alpha, tests, dim, beta=1, n=500, tolerance=1) -> dict:
    #Allows for tuning outside of test, partial is used
    pilot = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
    length_scale = median_heuristic(pilot)
    rbf_cost_fn = partial(rbf_kernel, length_scale=length_scale)
    polynomial_cost_fn = partial(polynomial_kernel, length_scale=length_scale)

    # Correctly-specified Gaussian detector: mean-only for a mean change,
    # variance-only for a variance change, and joint mean+variance for
    # everything else (skew/kurtosis/multimodal all leave first two moments
    # matched, so mean+variance is the closest well-specified Gaussian model,
    # even though it has no power against pure shape changes).
    if change_type_fn.__name__ == "mean_change":
        gaussian_cost_fn = gaussian_mean_change
    elif change_type_fn.__name__ == "variance_change":
        gaussian_cost_fn = gaussian_variance_change
    else:
        gaussian_cost_fn = gaussian_meanvar_change

    gaussian_beta = beta_tuning(alpha, gaussian_cost_fn, dim, n=n)
    rbf_beta = beta_tuning(alpha, rbf_cost_fn, dim, n=n)
    polynomial_beta = beta_tuning(alpha, polynomial_cost_fn, dim, n=n)
    oracle_mean_beta = oracle_beta_tuning_mean(alpha, dim, n=n)
    oracle_var_beta = oracle_beta_tuning_var(alpha, dim, n=n)

    # The skew/multimodal oracles are only valid for the change type whose
    # delta they were derived from (e.g. multimodal's delta must be in
    # [0, 1), but skewness/mean/etc. deltas routinely exceed 1), so only
    # tune and evaluate the one matching the change actually under test.
    is_skew_change = change_type_fn.__name__ == "skewness_change"
    is_multimodal_change = change_type_fn.__name__ == "multimodal_change"
    oracle_skew_beta = oracle_beta_tuning_skew(alpha, dim, delta, n=n) if is_skew_change else None
    oracle_multimodal_beta = oracle_beta_tuning_multimodal(alpha, dim, delta, n=n) if is_multimodal_change else None


    detectors = {
        "Gaussian": Detector(cost_function=gaussian_cost_fn, penalty=gaussian_beta),
        "RBF": Detector(cost_function=rbf_cost_fn, penalty=rbf_beta),
        "Polynomial": Detector(cost_function=polynomial_cost_fn, penalty=polynomial_beta),
    }
    counts = {"RBF": 0, "Gaussian": 0, "Polynomial": 0, "Oracle Mean": 0, "Oracle Var":0, "Oracle Skew": 0, "Oracle Multimodal": 0}
    changepoint = n//2

    for i in range(tests):
        ts = np.random.multivariate_normal(mean=np.ones(dim), cov=np.eye(dim), size=n)
        changepoint = n//2 
        ts_shifted = change_type_fn(ts, changepoint, delta, beta=beta)


        # Oracle already knows the true changepoint, so it just tests directly
        # at that one point instead of searching/localizing.
        if oracle_statistic_mean(timeseries=ts_shifted, t=changepoint) >= oracle_mean_beta:
            counts["Oracle Mean"] += 1

        if   oracle_statistic_var(timeseries=ts_shifted, t=changepoint) >= oracle_var_beta:
                counts["Oracle Var"] += 1

        if is_skew_change and oracle_statistic_skew(timeseries=ts_shifted, t=changepoint, delta=delta) >= oracle_skew_beta:
            counts["Oracle Skew"] += 1

        if is_multimodal_change and oracle_statistic_multimodal(timeseries=ts_shifted, t=changepoint, delta=delta) >= oracle_multimodal_beta:
            counts["Oracle Multimodal"] += 1

        for name, det in detectors.items():
             results = det.detect(time_series = ts_shifted)
             if results is not None and abs(results[0][0]- changepoint) <= tolerance:
                  counts[name] +=1

        

    counts = {k: v / tests for k, v in counts.items()}
    return counts

# %%
def smooth_curve(x, y, num=300):
    # Monotone cubic interpolation - smooths the line between MC-estimated
    # points without over/undershooting past their local min/max.
    x = np.asarray(x, dtype=float)
    y = np.asarray(y, dtype=float)
    x_smooth = np.linspace(x.min(), x.max(), num)
    y_smooth = PchipInterpolator(x, y)(x_smooth)
    return x_smooth, y_smooth

# %% [markdown]
# Here I will optimise my value of tolerance in order to see which value has a high power yet also has a low type 1 error.

# %%
#def power(change_type_fn, alpha, tests, dim, beta=1, n=500):
#    x = np.linspace(1, 4, 10)   # delta values swept, sample size held fixed at n
#    results = {"RBF": [], "Gaussian": [], "Laplacian": [], "Oracle Mean": []}
#    for i in x:
#        result = statistical_test_v1(change_type_fn=change_type_fn, delta=i, alpha=alpha, tests=tests, dim=dim, beta=beta, n=n)
#        results["RBF"].append(result["RBF"])
#        results["Gaussian"].append(result["Gaussian"])
#        results["Laplacian"].append(result["Laplacian"])
#        results["Oracle Mean"].append(result["Oracle Mean"])
#
#    fig, ax = plt.subplots(figsize=(7, 4.5))
#    fig.patch.set_facecolor("#fcfcfb")
#    ax.set_facecolor("#fcfcfb")
#
#    series = [
#        ("Gaussian", "#2a78d6"),
#        ("RBF", "#eb6834"),
#        ("Laplacian", "#1baf7a"),
#        ("Oracle Mean", "#722873"),
#    ]
#    for name, color in series:
#        xs, ys = smooth_curve(x, results[name])
#        ax.plot(xs, ys, label=name if name != "Oracle Mean" else "Oracle", color=color, linewidth=2)
#        ax.plot(x, results[name], "o", color=color, markersize=5)
#    ax.axhline(alpha, color="#898781", linestyle="--", linewidth=1, label=f"alpha = {alpha}")
#
#    ax.set_xlabel("delta", color="#52514e")
#    ax.set_ylabel("detection rate", color="#52514e")
#    ax.set_title(change_type_fn.__name__.replace("_", " ").title(), color="#0b0b0b", fontsize=13, fontweight="bold", loc="left")
#    ax.set_ylim(-0.05, 1.05)
#
#    ax.spines["top"].set_visible(False)
#    ax.spines["right"].set_visible(False)
#    ax.spines["left"].set_color("#c3c2b7")
#    ax.spines["bottom"].set_color("#c3c2b7")
#    ax.tick_params(colors="#898781")
#    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
#    ax.set_axisbelow(True)
#
#    ax.legend(frameon=False, labelcolor="#0b0b0b")
#    fig.tight_layout()
#    plt.show()
#
#power(change_type_fn=mean_change, alpha=0.05, tests=1000, dim=5)

# %% [markdown]
# Power as sample size increases, delta held fixed

# %%
def power_by_sample_size_mean(change_type_fn, alpha, delta, dim, beta=1, tests=1000, sample_sizes=None):
    if sample_sizes is None:
        sample_sizes = np.linspace(10, 200, 6).astype(int)
    results = {"RBF": [], "Gaussian": [], "Polynomial": [], "Oracle": []}

    for i in sample_sizes:
        result = statistical_test_v1(change_type_fn=change_type_fn, delta=delta, alpha=alpha, tests=tests, dim=dim, beta=beta, n=i, tolerance=0.02 * i)
        results["RBF"].append(result["RBF"])
        results["Gaussian"].append(result["Gaussian"])
        results["Polynomial"].append(result["Polynomial"])
        results["Oracle"].append(result["Oracle Mean"])

    pd.DataFrame({"n": sample_sizes, **results}).to_csv(f"data/power_{change_type_fn.__name__}_1.csv", index=False)

    fig, ax = plt.subplots(figsize=(7, 4.5))
    fig.patch.set_facecolor("#fcfcfb")
    ax.set_facecolor("#fcfcfb")

    series = [
        ("Gaussian", "#2a78d6"),
        ("RBF", "#eb6834"),
        ("Polynomial", "#d64a8a"),
        ("Oracle", "#722873"),
    ]
    for name, color in series:
        xs, ys = smooth_curve(sample_sizes, results[name])
        ax.plot(xs, ys, label=name, color=color, linewidth=2)
        ax.plot(sample_sizes, results[name], "o", color=color, markersize=5)
    ax.axhline(alpha, color="#898781", linestyle="--", linewidth=1, label=f"alpha = {alpha}")

    ax.set_xlabel("sample size (n)", color="#52514e")
    ax.set_ylabel("detection rate", color="#52514e")
    ax.set_title(change_type_fn.__name__.replace("_", " ").title() + f"  (delta={delta})",
                 color="#0b0b0b", fontsize=13, fontweight="bold", loc="left")
    ax.set_ylim(-0.05, 1.05)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#c3c2b7")
    ax.spines["bottom"].set_color("#c3c2b7")
    ax.tick_params(colors="#898781")
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
    ax.set_axisbelow(True)

    ax.legend(frameon=False, labelcolor="#0b0b0b")
    fig.tight_layout()
    fig.savefig(f"plots/power_{change_type_fn.__name__}.png", dpi=150, bbox_inches="tight")
    plt.show()

power_by_sample_size_mean(change_type_fn=mean_change, alpha=0.05, delta=1.5, dim=1)

# %%
def power_by_sample_size_variance(change_type_fn, alpha, delta, dim, beta=1, tests=1000, sample_sizes=None):
    if sample_sizes is None:
        sample_sizes = np.linspace(10, 200, 5).astype(int)
    results = {"RBF": [], "Gaussian": [], "Polynomial": [], "Oracle": []}

    for i in sample_sizes:
        result = statistical_test_v1(change_type_fn=change_type_fn, delta=delta, alpha=alpha, tests=tests, dim=dim, beta=beta, n=i, tolerance=0.02 * i)
        results["RBF"].append(result["RBF"])
        results["Gaussian"].append(result["Gaussian"])
        results["Polynomial"].append(result["Polynomial"])
        results["Oracle"].append(result["Oracle Var"])

    pd.DataFrame({"n": sample_sizes, **results}).to_csv(f"data/power_{change_type_fn.__name__}_1.csv", index=False)

    fig, ax = plt.subplots(figsize=(7, 4.5))
    fig.patch.set_facecolor("#fcfcfb")
    ax.set_facecolor("#fcfcfb")

    series = [
        ("Gaussian", "#2a78d6"),
        ("RBF", "#eb6834"),
        ("Polynomial", "#d64a8a"),
        ("Oracle", "#722873"),
    ]
    for name, color in series:
        xs, ys = smooth_curve(sample_sizes, results[name])
        ax.plot(xs, ys, label=name, color=color, linewidth=2)
        ax.plot(sample_sizes, results[name], "o", color=color, markersize=5)
    ax.axhline(alpha, color="#898781", linestyle="--", linewidth=1, label=f"alpha = {alpha}")

    ax.set_xlabel("sample size (n)", color="#52514e")
    ax.set_ylabel("detection rate", color="#52514e")
    ax.set_title(change_type_fn.__name__.replace("_", " ").title() + f"  (delta={delta})",
                 color="#0b0b0b", fontsize=13, fontweight="bold", loc="left")
    ax.set_ylim(-0.05, 1.05)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#c3c2b7")
    ax.spines["bottom"].set_color("#c3c2b7")
    ax.tick_params(colors="#898781")
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
    ax.set_axisbelow(True)

    ax.legend(frameon=False, labelcolor="#0b0b0b")
    fig.tight_layout()
    fig.savefig(f"plots/power_{change_type_fn.__name__}.png", dpi=150, bbox_inches="tight")
    plt.show()

power_by_sample_size_variance(change_type_fn=variance_change, alpha=0.05, delta=2, dim=1)

# %%
def power_by_sample_size_skewness(change_type_fn, alpha, delta, dim, beta=1, tests=1000, sample_sizes=None):
    if sample_sizes is None:
        sample_sizes = np.linspace(10, 2000, 9).astype(int)
    results = {"RBF": [], "Gaussian": [], "Polynomial": [], "Oracle": []}

    for i in sample_sizes:
        result = statistical_test_v1(change_type_fn=change_type_fn, delta=delta, alpha=alpha, tests=tests, dim=dim, beta=beta, n=i, tolerance=0.02 * i)
        results["RBF"].append(result["RBF"])
        results["Gaussian"].append(result["Gaussian"])
        results["Polynomial"].append(result["Polynomial"])
        results["Oracle"].append(result["Oracle Skew"])

    pd.DataFrame({"n": sample_sizes, **results}).to_csv(f"data/power_{change_type_fn.__name__}_1.csv", index=False)

    fig, ax = plt.subplots(figsize=(7, 4.5))
    fig.patch.set_facecolor("#fcfcfb")
    ax.set_facecolor("#fcfcfb")

    series = [
        ("Gaussian", "#2a78d6"),
        ("RBF", "#eb6834"),
        ("Polynomial", "#d64a8a"),
        ("Oracle", "#722873"),
    ]
    for name, color in series:
        xs, ys = smooth_curve(sample_sizes, results[name])
        ax.plot(xs, ys, label=name, color=color, linewidth=2)
        ax.plot(sample_sizes, results[name], "o", color=color, markersize=5)
    ax.axhline(alpha, color="#898781", linestyle="--", linewidth=1, label=f"alpha = {alpha}")

    ax.set_xlabel("sample size (n)", color="#52514e")
    ax.set_ylabel("detection rate", color="#52514e")
    ax.set_title(change_type_fn.__name__.replace("_", " ").title() + f"  (delta={delta})",
                 color="#0b0b0b", fontsize=13, fontweight="bold", loc="left")
    ax.set_ylim(-0.05, 1.05)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#c3c2b7")
    ax.spines["bottom"].set_color("#c3c2b7")
    ax.tick_params(colors="#898781")
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
    ax.set_axisbelow(True)

    ax.legend(frameon=False, labelcolor="#0b0b0b")
    fig.tight_layout()
    fig.savefig(f"plots/power_{change_type_fn.__name__}.png", dpi=150, bbox_inches="tight")
    plt.show()

power_by_sample_size_skewness(change_type_fn=skewness_change, alpha=0.05, delta=8, dim=1,
                              sample_sizes=np.unique(np.geomspace(10, 2000, 8).astype(int)))

# %%
def power_by_sample_size_kurtosis(change_type_fn, alpha, delta, dim, beta=1, tests=1000, sample_sizes=None):
    if sample_sizes is None:
        sample_sizes = np.linspace(10, 2000, 9).astype(int)
    results = {"RBF": [], "Gaussian": [], "Polynomial": []}

    for i in sample_sizes:
        result = statistical_test_v1(change_type_fn=change_type_fn, delta=delta, alpha=alpha, tests=tests, dim=dim, beta=beta, n=i, tolerance=0.02 * i)
        results["RBF"].append(result["RBF"])
        results["Gaussian"].append(result["Gaussian"])
        results["Polynomial"].append(result["Polynomial"])

    pd.DataFrame({"n": sample_sizes, **results}).to_csv(f"data/power_{change_type_fn.__name__}_1.csv", index=False)

    fig, ax = plt.subplots(figsize=(7, 4.5))
    fig.patch.set_facecolor("#fcfcfb")
    ax.set_facecolor("#fcfcfb")

    series = [
        ("Gaussian", "#2a78d6"),
        ("RBF", "#eb6834"),
        ("Polynomial", "#d64a8a"),
    ]
    for name, color in series:
        xs, ys = smooth_curve(sample_sizes, results[name])
        ax.plot(xs, ys, label=name, color=color, linewidth=2)
        ax.plot(sample_sizes, results[name], "o", color=color, markersize=5)
    ax.axhline(alpha, color="#898781", linestyle="--", linewidth=1, label=f"alpha = {alpha}")

    ax.set_xlabel("sample size (n)", color="#52514e")
    ax.set_ylabel("detection rate", color="#52514e")
    ax.set_title(change_type_fn.__name__.replace("_", " ").title() + f"  (delta={delta})",
                 color="#0b0b0b", fontsize=13, fontweight="bold", loc="left")
    ax.set_ylim(-0.05, 1.05)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#c3c2b7")
    ax.spines["bottom"].set_color("#c3c2b7")
    ax.tick_params(colors="#898781")
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
    ax.set_axisbelow(True)

    ax.legend(frameon=False, labelcolor="#0b0b0b")
    fig.tight_layout()
    fig.savefig(f"plots/power_{change_type_fn.__name__}.png", dpi=150, bbox_inches="tight")
    plt.show()

power_by_sample_size_kurtosis(change_type_fn=kurtosis_change, alpha=0.05, delta=4.5, dim=1,
                              sample_sizes=np.unique(np.geomspace(10, 2000, 8).astype(int)))

# %%
def power_by_sample_size_multimodal(change_type_fn, alpha, delta, dim, beta=1, tests=1000, sample_sizes=None):
    if sample_sizes is None:
        sample_sizes = np.linspace(10, 2000, 9).astype(int)
    results = {"RBF": [], "Gaussian": [], "Polynomial": [], "Oracle": []}

    for i in sample_sizes:
        result = statistical_test_v1(change_type_fn=change_type_fn, delta=delta, alpha=alpha, tests=tests, dim=dim, beta=beta, n=i, tolerance=0.02 * i)
        results["RBF"].append(result["RBF"])
        results["Gaussian"].append(result["Gaussian"])
        results["Polynomial"].append(result["Polynomial"])
        results["Oracle"].append(result["Oracle Multimodal"])

    pd.DataFrame({"n": sample_sizes, **results}).to_csv(f"data/power_{change_type_fn.__name__}_1.csv", index=False)

    fig, ax = plt.subplots(figsize=(7, 4.5))
    fig.patch.set_facecolor("#fcfcfb")
    ax.set_facecolor("#fcfcfb")

    series = [
        ("Gaussian", "#2a78d6"),
        ("RBF", "#eb6834"),
        ("Polynomial", "#d64a8a"),
        ("Oracle", "#722873"),
    ]
    for name, color in series:
        xs, ys = smooth_curve(sample_sizes, results[name])
        ax.plot(xs, ys, label=name, color=color, linewidth=2)
        ax.plot(sample_sizes, results[name], "o", color=color, markersize=5)
    ax.axhline(alpha, color="#898781", linestyle="--", linewidth=1, label=f"alpha = {alpha}")

    ax.set_xlabel("sample size (n)", color="#52514e")
    ax.set_ylabel("detection rate", color="#52514e")
    ax.set_title(change_type_fn.__name__.replace("_", " ").title() + f"  (delta={delta})",
                 color="#0b0b0b", fontsize=13, fontweight="bold", loc="left")
    ax.set_ylim(-0.05, 1.05)

    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.spines["left"].set_color("#c3c2b7")
    ax.spines["bottom"].set_color("#c3c2b7")
    ax.tick_params(colors="#898781")
    ax.grid(axis="y", color="#e1e0d9", linewidth=0.8)
    ax.set_axisbelow(True)

    ax.legend(frameon=False, labelcolor="#0b0b0b")
    fig.tight_layout()
    fig.savefig(f"plots/power_{change_type_fn.__name__}.png", dpi=150, bbox_inches="tight")
    plt.show()

power_by_sample_size_multimodal(change_type_fn=multimodal_change, alpha=0.05, delta=0.95, dim=1,
                                sample_sizes=np.unique(np.geomspace(10, 2000, 8).astype(int)))

# %% [markdown]
# **Possible ways I could build it further**
# 1) A oracle test
# 2) Compare against the Epps-Singleton test, t test, CVM

# %% [markdown]
# What is the Laplace Test, this is a centroid test that is a measure of observed arrival times with mid point of the period of observation. This

# %% [markdown]
# Possible question:
# https://proceedings.neurips.cc/paper_files/paper/2008/file/08b255a5d42b89b0585260b6f2360bdd-Paper.pdf

# %% [markdown]
# Length Scales, What are their purpose. Length scales are used in Mathematics in order

# %% [markdown]
# **Now We will further be looking into kernel fisher discriminant ratios**
#
# The kernel fisher discriminant ratio is an objective function used in ML for non-linear classification and dimensioanlity reduction , maximises the spread between sets and reduce the variance in between them.
#
# **The ratio**
#
# $$ \frac{\text{between-class Var}}{\text{Within class Var}}$$
#
#
# A higher ratio means classes are better seperated relative to their spread
#
# This has further links to SVMs as it tries to maximize ratio between class averages and class varaicnce, where SVMs focus on boundary points.
#
# **How does the code work**
#
# The clode slides a divider along the data and at each position it scores how unlike each of the 2 halves look. It returns one score per position so the output it more like a curve.
#
# Firstly we must calibrate a sense of scale, it measures distances between points as a yardstick.
#
# After it builds a similarity table. This creating a number near 1 if similar otherwise 0 if not. It is looking for if the two halves come from different populations.
#
# After it draws a divider and scores it for every sungle position e.g. 11, positio 12 etc etec. After getting a full list of score you take the point on the curve with the highest point and that is your changepoint.
#
# After we get this max statistic, we can use montecarlo methods to find a threshold to either accept or reject to find
#
# Where MMD is the Euclidean distance between the two mean embedding while KFDR is a Mahalanobis distance
#
# This Mahalanobis distance is used to find outliers, and is a multivariate gernealisation of the Z score which intrestingly enough was used to counter eugenics.

# %% [markdown]
# The next area of this project is that I would like to ake it into the direction of Handling serial dependence, Non-IID Null data for this week
# A vague idea of what I had in mind when I first proposed this project:
# 1. Decide on some selection of changepoints. An example set may be, gaussian change in mean, gaussian change in variance, gaussian change to some heavier tailed distribution (and many else, if you want to). There are also options for going from 1 dimension to higher dimensions.
# 2. For each change, design a correctly specified parametric detector, using cost functions designed to look for the changes we are actually searching for. Get the type of power graphs we have been talking about from these.
# 3. Now, try and detect the same changes with kernel based methods.
# (the following questions may seem a bit boring, and in all honesty they might be. However they are genuinely important to have a good answer to. I currently do not have good answers to all of them)
# a. how should each detector be set up? What is the null hypothesis we are supposing, hence how should we tune the threshold beta?
# b. how should we pick the length scale? Re run the tuning on every sample? what about if we fix it beforehand whilst we are doing monte carlo sim to get some false positive rate.
# 4. Compare multiple kernels to one another. Does one capture changes in tail behaviour noticeable easier? do some work better for different types of change? e.g., for gaussian change in mean perhaps rbf is best, but for lorentzian change in mean, maybe a different kernel does better.
# 5. (optional) is there any theory we can do to support any conclusions we find in step 4?
#
#
# I will work on these 2 first to finish off my project
#
# 1. Handling Serial Dependence (Non-IID Null)
# Standard kernel changepoint tests assume independent and identically distributed (i.i.d.) samples within segments. In real-world time series, autocorrelation creates false alarms because time dependence mimics distribution shifts.
# The Direction: Incorporate block bootstrap methods (e.g., moving block bootstrap) or spectral correction to maintain valid control of the false positive rate under auto-correlated noise.
# Why It Matters: Demonstrating when standard kernel CPD fails on dependent data provides immediate practical relevance.
#
# ​
# to attribute changes back to specific dimensions, features, or moments.
# Why It Matters: Transforms an abstract non-parametric detector into a diagnostic tool.
